# %% [markdown]
# # Importamos librerías

# %%
import tensorflow as tf
import pathlib
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import keras

# %% [markdown]
# # Primera prueba(Imagen propia)

# %% [markdown]
# ## Importamos imagen de pureba

# %%
#path1 = '../../../../Data/Processed/img_prop/01.jpg'
path1 = r'D:\Documentos de trabajo\Maestría\Curso Maestría Introducción a Redes Neuronales\Tarea 2\Tarea 2. Reconocimiento facial\Tareea2.-Curso-Redes-Neuronales.-Rafael-S-nchez-Cedillo\Data\Processed\img_prop\01.jpg'

# %%
or_prueba1 = tf.keras.preprocessing.image.load_img(path1)
or_prueba1 = tf.image.resize(or_prueba1, [178,218])
or_prueba1 /= 255.0 
print(or_prueba1.shape)
print(or_prueba1.dtype)
# Out:
# (178, 218, 3)
# <dtype: 'float32'>

# %%
plt.imshow(or_prueba1)

# %%
or_prueba1 =or_prueba1[None, :]

# %% [markdown]
# ## Importamos el modelo y hacemos predicciones

# %%
new_model = keras.models.load_model('FE.h5')

# %%
new_predictions = new_model.predict(or_prueba1)
print(new_predictions)
# Out:
# 1/1 [==============================] - 0s 113ms/step
# [[0.9767761]]

# %%
new_predictions = new_predictions.round()

# %%
new_predictions
# Out:
# array([[1.]], dtype=float32)

# %%
if new_predictions== 1:
    print("No es Rafael")
else: 
    print("Es Rafael")
# Out:
# No es Rafael

# %% [markdown]
# # Segunda prueba

# %% [markdown]
# ## Importamos imagen

# %%
#path2 = '../../../../Data/Processed/img_prop/descarga.jpg'
path2 = r'D:\Documentos de trabajo\Maestría\Curso Maestría Introducción a Redes Neuronales\Tarea 2\Tarea 2. Reconocimiento facial\Tareea2.-Curso-Redes-Neuronales.-Rafael-S-nchez-Cedillo\Data\Processed\img_prop\descarga.jpg'

# %%
or_prueba2 = tf.keras.preprocessing.image.load_img(path2)
or_prueba2 = tf.image.resize(or_prueba2, [178,218])
or_prueba2 /= 255.0 
print(or_prueba2.shape)
print(or_prueba2.dtype)
# Out:
# (178, 218, 3)
# <dtype: 'float32'>

# %%
plt.imshow(or_prueba2)

# %%
or_prueba2 =or_prueba2[None, :]

# %% [markdown]
# ## Importamos el modelo y hacemos predicciones

# %%
new_predictions_2 = new_model.predict(or_prueba2)
print(new_predictions_2)
# Out:
# 1/1 [==============================] - 0s 15ms/step
# [[0.99928194]]

# %%
new_predictions_2 = new_predictions_2.round()

# %%
if new_predictions_2== 1:
    print("No es Rafael")
else: 
    print("Es Rafael")
# Out:
# No es Rafael

# %% [markdown]
# # Tercera Prueba

# %%
path3 = r'D:\Documentos de trabajo\Maestría\Curso Maestría Introducción a Redes Neuronales\Tarea 2\Tarea 2. Reconocimiento facial\Tareea2.-Curso-Redes-Neuronales.-Rafael-S-nchez-Cedillo\Data\Recognize_me\Train\Me\FAE250FC-2510-4676-9750-8374A8FCC622.jpg'
#path3 = '../../../../Data/Recognize_me/Train/Me/FAE250FC-2510-4676-9750-8374A8FCC622.jpg'

# %%
or_prueba3 = tf.keras.preprocessing.image.load_img(path3)
or_prueba3 = tf.image.resize(or_prueba3, [178,218])
or_prueba3 /= 255.0 
print(or_prueba3.shape)
print(or_prueba3.dtype)
# Out:
# (178, 218, 3)
# <dtype: 'float32'>

# %%
plt.imshow(or_prueba3)

# %%
or_prueba3 =or_prueba3[None, :]

# %% [markdown]
# ## Importamos el modelo y hacemos predicciones

# %%
new_predictions_3 = new_model.predict(or_prueba3)
print(new_predictions_3)
# Out:
# 1/1 [==============================] - 0s 15ms/step
# [[0.15093784]]

# %%
new_predictions_3 = new_predictions_3.round()

# %%
if new_predictions_3== 1:
    print("No es Rafael")
else: 
    print("Es Rafael")
# Out:
# Es Rafael
