# %%
import os
mypath='../../Data/Processed/img_align_celeba/'
allimage = os.listdir(mypath)
allimage
# Out:
# ['000001.jpg',
#  '000002.jpg',
#  '000003.jpg',
#  '000004.jpg',
#  '000005.jpg',
#  '000006.jpg',
#  '000007.jpg',
#  '000008.jpg',
#  '000009.jpg',
#  '000010.jpg',
#  '000011.jpg',
#  '000012.jpg',
#  '000013.jpg',
#  '000014.jpg',
#  '000015.jpg',
#  '000016.jpg',
#  '000017.jpg',
#  '000018.jpg',
#  '000019.jpg',
#  '000020.jpg',
#  '000021.jpg',
#  '000022.jpg',
#  '000023.jpg',
#  '000024.jpg',
#  '000025.jpg',
#  '000026.jpg',
#  '000027.jpg',
#  '000028.jpg',
#  '000029.jpg',
#  '000030.jpg',
#  '000031.jpg',
#  '000032.jpg',
#  '000033.jpg',
#  '000034.jpg',
#  '000035.jpg',
#  '000036.jpg',
#  '000037.jpg',
#  '000038.jpg',
#  '000039.jpg',
#  '000040.jpg',
#  '000041.jpg',
#  '000042.jpg',
#  '000043.jpg',
#  '000044.jpg',
#  '000045.jpg',
#  '000046.jpg',
#  '000047.jpg',
#  '000048.jpg',
#  '000049.jpg',
#  '000050.jpg',
#  '000051.jpg',
#  '000052.jpg',
#  '000053.jpg',
#  '000054.jpg',
#  '000055.jpg',
#  '000056.jpg',
#  '000057.jpg',
#  '000058.jpg',
# ...

# %%
import pandas as pd
allimagedf = pd.DataFrame(allimage,columns = ['Image'])
sample_imagedf = allimagedf.sample(frac =0.00247, random_state=1)
sample_imagedf
# Out:
#              Image
# 57205   057206.jpg
# 75512   075513.jpg
# 193254  193255.jpg
# 125591  125592.jpg
# 75806   075807.jpg
# ...            ...
# 90956   090957.jpg
# 148583  148584.jpg
# 157311  157312.jpg
# 199353  199354.jpg
# 120361  120362.jpg
#
# [500 rows x 1 columns]

# %%
sample_image = list(sample_imagedf['Image'])
sample_image
# Out:
# ['057206.jpg',
#  '075513.jpg',
#  '193255.jpg',
#  '125592.jpg',
#  '075807.jpg',
#  '093800.jpg',
#  '072050.jpg',
#  '003819.jpg',
#  '146129.jpg',
#  '082920.jpg',
#  '050103.jpg',
#  '037093.jpg',
#  '075608.jpg',
#  '037079.jpg',
#  '070722.jpg',
#  '023139.jpg',
#  '009130.jpg',
#  '019138.jpg',
#  '119985.jpg',
#  '031059.jpg',
#  '007242.jpg',
#  '174854.jpg',
#  '054484.jpg',
#  '140006.jpg',
#  '134805.jpg',
#  '185464.jpg',
#  '047433.jpg',
#  '158913.jpg',
#  '166285.jpg',
#  '062491.jpg',
#  '033116.jpg',
#  '176698.jpg',
#  '195664.jpg',
#  '126774.jpg',
#  '029553.jpg',
#  '091425.jpg',
#  '040923.jpg',
#  '152895.jpg',
#  '080196.jpg',
#  '037346.jpg',
#  '073778.jpg',
#  '025069.jpg',
#  '037761.jpg',
#  '078448.jpg',
#  '060489.jpg',
#  '156936.jpg',
#  '081245.jpg',
#  '070880.jpg',
#  '055308.jpg',
#  '065845.jpg',
#  '024167.jpg',
#  '182410.jpg',
#  '152184.jpg',
#  '044230.jpg',
#  '061274.jpg',
#  '094227.jpg',
#  '012915.jpg',
#  '095315.jpg',
# ...

# %%
len(sample_image)
# Out:
# 500

# %%
new_path = '../../Data/Recognize_me/Others'

# %%
import shutil
import glob

for i in range(0,500): 
    old_path = os.path.join(mypath,sample_image[i])
    shutil.copy(old_path, new_path)
